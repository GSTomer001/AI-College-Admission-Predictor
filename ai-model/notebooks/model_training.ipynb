# %% [markdown]
# # Model Training Exploration
#
# Interactive exploration of the admission dataset and model. The authoritative
# training pipeline lives in `../train.py` — this notebook is for experimentation.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from preprocessing.preprocess import load_training_data

X, y = load_training_data()
df = pd.DataFrame(X, columns=['gre','toefl','rating','sop','lor','cgpa','research'])
df['chance'] = y
df.describe()
